# %%
'''
This notebook was takes the Java methods in "preprocessed_final.csv" and tokenizes them. Then it splits the data
up into train, eval, and test sets. The split data is then saved to txt files.
'''

# %%
import pandas as pd

# %%
import sys
import time
from pygments.lexers.jvm import JavaLexer
from pygments.lexers import get_lexer_by_name
from pygments.token import Token

def print_progress(percent):
    width = 50  # Width of the progress bar
    filled = int(width * percent / 100)
    bar = "#" * filled + "-" * (width - filled)
    sys.stdout.write(f"\r[{bar}] {percent}%")
    sys.stdout.flush()

def tokenize_methods_from_dataframe(df: pd.DataFrame, method_column: str, language: str) -> pd.DataFrame:
    """
    Tokenize the methods in method_column

    Args:
        df (pd.DataFrame): DataFrame containing the methods.
        method_column (str): Column name containing the Java methods.
        language (str): Programming language for the lexer (e.g., 'java').

    Returns:
        pd.DataFrame: Updated DataFrame with a new column 'Tokenized Method'.
    """
    train_size = len(df[method_column])
    count=0
    def tokenize_method(code):
        lexer = get_lexer_by_name("Java")
        tokens = []
        in_function_declaration = False
        in_arguments = False
        arguments = {}
        arg_num = 0
        for t in lexer.get_tokens(code):
            if t[0] in Token.Text:
              continue
            if t[0] in Token.Name.Function:
                tokens.append("function")
                in_function_declaration = True
            elif in_arguments and t[0] in Token.Name and not (t[1][0].isupper()):
                arguments[t[1]] = "arg" + str(arg_num)
                arg_num += 1
                tokens.append(arguments[t[1]])
            elif t[1] in arguments.keys():
                tokens.append(arguments[t[1]])
            else:
                tokens.append(t[1])
            if in_function_declaration and t[1] == '(':
                in_arguments = True
                continue
            if in_arguments and t[1] == ')':
                in_arguments = False
                in_function_declaration = False
                continue
        nonlocal count
        count += 1

        if count%250 == 0:
            print_progress(int((count/train_size)*100))
            time.sleep(0.05)

        return tokens

    # Apply the function to the specified column and add a new column with the results
    df["Tokenized Method"] = df[method_column].apply(tokenize_method)
    print_progress(100)
    print()
    return df

# %%
df = pd.read_csv("preprocessed_final.csv")

# %%
all_untokenized_methods = list(df['Method No Comments'])

# %%
tokenized_df = tokenize_methods_from_dataframe(df, "Method No Comments", "java")
# Out:
# [##################################################] 100%

# %%
df_shuffled = tokenized_df.sample(frac=1, random_state=42)  # Shuffle rows
train_size = int(0.8 * len(df))  # 80%
eval_size = int(0.1 * len(df))    # 10%

# Split the DataFrame
train_df = df_shuffled.iloc[:train_size]
eval_df = df_shuffled.iloc[train_size:train_size + eval_size]
test_df = df_shuffled.iloc[train_size + eval_size:]

# %%
def save_tokenized_method_to_txt(df: pd.DataFrame, filename: str):
  lines = []
  for index, row in df.iterrows():
    lines.append(" ".join(row["Tokenized Method"])+"\n")

  with open(filename, "w",  encoding="utf-8") as f:
    f.writelines(lines)

# %%
save_tokenized_method_to_txt(train_df, "student_train.txt")

# %%
save_tokenized_method_to_txt(test_df, "test.txt")

# %%
save_tokenized_method_to_txt(eval_df, "eval.txt")

# %%
test_df_100 = test_df.sample(n=100, random_state=42)

# %%
test_df_100
# Out:
#                                     Commit Hash  \
# 21534  1f89ec7101c872b2d0579d1e24847d69e6664ef8
# 8356   13c82bbfdb768c67f364a5e6ab57267777234303
# 11383  89e93009ea58b35e20a89fd896be6d8d97cc6e33
# 4760   3afde5830e5bc811dfaf214be86652e2c1f95489
# 2568   01a62698797658b0f51d323fdfb5e9744d843773
# ...                                         ...
# 19063  13e373af765416613e66d2ecc1134a6edad57368
# 22984  464aa80fb3a3ad6d8c38b6efe5e81663b9ddf737
# 19528  3ebcd63cf7116f700eae47fcc2429bb23401c14c
# 17082  eae2b0b57cb0e7810750932ac8549515766c5c89
# 11704  78c10ee651d0c8317971982cbcfdf963aabc8285
#
#                                File Name                       Method Name  \
# 21534        HeaderRequestExtractor.java                         doExtract
# 8356                  InvokeJCLTest.java                      testPrintAPI
# 11383                 LoggerFactory.java  reportIgnoredStaticLoggerBinders
# 4760                    ElementTest.java          testShallowCloneToString
# 2568                HtmlTreeBuilder.java               clearStackToContext
# ...                                  ...                               ...
# 19063                          Moco.java                             proxy
# 22984                   JsonSupport.java                      assertEquals
# 19528  AbstractProxyResponseHandler.java                   writeToResponse
# 17082              HttpServerParser.java                  createHttpServer
# 11704           EventRecodingLogger.java                              info
#
#                                              Method Code  \
# 21534      protected Optional<String[]> doExtract(fin...
# 8356     public void testPrintAPI() {\n    Log log = ...
# 11383      private static void reportIgnoredStaticLog...
# 4760       public void testShallowCloneToString() {\n...
# 2568       private void clearStackToContext(String......
# ...                                                  ...
# 19063      public static ResponseHandler proxy(final ...
# 22984      public static void assertEquals(final Stri...
# 19528      public void writeToResponse(final SessionC...
# 17082      private HttpServer createHttpServer(List<S...
# 11704  \tpublic void info(String format, Object arg1,...
#
#                                              Commit Link  \
# 21534  https://www.github.com/dreamhead/moco/commit/1...
# 8356   https://www.github.com/qos-ch/slf4j/commit/13c...
# 11383  https://www.github.com/qos-ch/slf4j/commit/89e...
# 4760   https://www.github.com/jhy/jsoup/commit/3afde5...
# 2568   https://www.github.com/jhy/jsoup/commit/01a626...
# ...                                                  ...
# 19063  https://www.github.com/dreamhead/moco/commit/1...
# 22984  https://www.github.com/dreamhead/moco/commit/4...
# 19528  https://www.github.com/dreamhead/moco/commit/3...
# 17082  https://www.github.com/dreamhead/moco/commit/e...
# 11704  https://www.github.com/qos-ch/slf4j/commit/78c...
#
#                                       Method No Comments  \
# 21534      protected Optional<String[]> doExtract(fin...
# 8356     public void testPrintAPI() {\n    Log log = ...
# 11383      private static void reportIgnoredStaticLog...
# 4760       public void testShallowCloneToString() {\n...
# 2568       private void clearStackToContext(String......
# ...                                                  ...
# 19063      public static ResponseHandler proxy(final ...
# 22984      public static void assertEquals(final Stri...
# 19528      public void writeToResponse(final SessionC...
# 17082      private HttpServer createHttpServer(List<S...
# 11704  \tpublic void info(String format, Object arg1,...
#
#                                         Tokenized Method
# 21534  [protected, Optional, <, String, [, ], >, func...
# 8356   [public, void, function, (, ), {, Log, log, =,...
# 11383  [private, static, void, function, (, Set, <, U...
# 4760   [public, void, function, (, ), {, Document, do...
# 2568   [private, void, function, (, String, ., ., ., ...
# ...                                                  ...
# 19063  [public, static, ResponseHandler, function, (,...
# 22984  [public, static, void, function, (, final, Str...
# 19528  [public, void, function, (, final, SessionCont...
# 17082  [private, HttpServer, function, (, List, <, Se...
# 11704  [public, void, function, (, String, arg0, ,, O...
#
# [100 rows x 7 columns]

# %%
save_tokenized_method_to_txt(test_df_100, "test_100.txt")
